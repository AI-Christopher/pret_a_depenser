# %%
import pandas as pd
import json
import os
import numpy as np
from scipy.stats import ks_2samp

# --- CONFIGURATION ---
BASE_DIR = ".."
REF_DATA_PATH = os.path.join(BASE_DIR, "datas/02_preprocess/datas.csv")
PROD_LOG_PATH = os.path.join(BASE_DIR, "api/production_logs/prediction_log.jsonl")
REPORT_OUTPUT_PATH = os.path.join(BASE_DIR, "reports/monitoring_report_complete.html")

os.makedirs(os.path.dirname(REPORT_OUTPUT_PATH), exist_ok=True)

# --- 1. CHARGEMENT DONNÉES DE RÉFÉRENCE ---
print("1️⃣ Chargement Référence...")
df_ref = pd.read_csv(REF_DATA_PATH, index_col=0)
if 'TARGET' in df_ref.columns:
    df_ref = df_ref.drop(columns=['TARGET'])

# --- 2. ANALYSE OPÉRATIONNELLE (Latence & Erreurs) ---
print("2️⃣ Analyse des Logs Opérationnels...")

total_calls = 0
errors = 0
latencies = []
prod_records = []

if os.path.exists(PROD_LOG_PATH):
    with open(PROD_LOG_PATH, 'r') as f:
        for line in f:
            try:
                log = json.loads(line)
                total_calls += 1
                
                # Récupération latence
                if 'latency_ms' in log:
                    latencies.append(log['latency_ms'])
                
                # Vérification statut
                if log.get('status') == 'FAILURE':
                    errors += 1
                elif log.get('status') == 'SUCCESS':
                    # On garde les features pour le drift seulement si succès
                    if 'input_features' in log:
                        prod_records.append(log['input_features'])
            except:
                continue

# Calcul des métriques opérationnelles
error_rate = (errors / total_calls) * 100 if total_calls > 0 else 0
avg_latency = np.mean(latencies) if latencies else 0
max_latency = np.max(latencies) if latencies else 0

# --- 3. PRÉPARATION DONNÉES DRIFT ---
print("3️⃣ Préparation Analyse Drift...")
if not prod_records:
    print("⚠️ Pas de logs succès. Utilisation échantillon fictif.")
    df_prod = df_ref.sample(50)
else:
    df_prod = pd.DataFrame.from_records(prod_records)
    # Alignement colonnes et types
    df_prod = df_prod.reindex(columns=df_ref.columns)
    df_prod = df_prod.fillna(0).astype(float, errors='ignore')

# --- 4. CALCUL DU DRIFT (Algorithme KS) ---
drift_results = []
alerts_drift = 0

numeric_cols = df_ref.select_dtypes(include=[np.number]).columns
common_cols = [c for c in numeric_cols if c in df_prod.columns]

for col in common_cols:
    data_ref = df_ref[col].dropna()
    data_prod = df_prod[col].dropna()
    
    if len(data_prod) < 5: continue
        
    # Test statistique
    stat, p_value = ks_2samp(data_ref, data_prod)
    is_drift = p_value < 0.05
    
    if is_drift: alerts_drift += 1
    
    drift_results.append({
        "Feature": col,
        "P-Value": round(p_value, 4),
        "Drift": "🔴 OUI" if is_drift else "🟢 NON",
        "Moy Ref": round(data_ref.mean(), 2),
        "Moy Prod": round(data_prod.mean(), 2)
    })

df_drift = pd.DataFrame(drift_results)
if not df_drift.empty:
    df_drift = df_drift.sort_values(by="P-Value")

# --- 5. GÉNÉRATION RAPPORT HTML COMPLET ---
print("4️⃣ Génération du Rapport...")

html_content = f"""
<html>
<head>
    <title>Rapport de Monitoring ML</title>
    <style>
        body {{ font-family: 'Segoe UI', Arial, sans-serif; margin: 40px; background-color: #f4f6f9; }}
        h1, h2 {{ color: #2c3e50; }}
        .card {{ background: white; padding: 20px; border-radius: 8px; box-shadow: 0 2px 5px rgba(0,0,0,0.1); margin-bottom: 20px; }}
        .metric-box {{ display: inline-block; width: 30%; text-align: center; }}
        .metric-val {{ font-size: 24px; font-weight: bold; color: #3498db; }}
        .metric-label {{ color: #7f8c8d; }}
        .alert {{ color: #e74c3c; }}
        table {{ border-collapse: collapse; width: 100%; font-size: 14px; }}
        th, td {{ border: 1px solid #ddd; padding: 12px; text-align: left; }}
        th {{ background-color: #34495e; color: white; }}
        tr:nth-child(even) {{ background-color: #f9f9f9; }}
    </style>
</head>
<body>
    <h1>🛡️ Dashboard de Monitoring API</h1>
    <p>Généré le : {pd.Timestamp.now()}</p>

    <div class="card">
        <h2>⚙️ Performance Opérationnelle</h2>
        <div class="metric-box">
            <div class="metric-val" style="color: {'red' if error_rate > 0 else 'green'}">{error_rate:.1f}%</div>
            <div class="metric-label">Taux d'Erreur</div>
        </div>
        <div class="metric-box">
            <div class="metric-val">{avg_latency:.1f} ms</div>
            <div class="metric-label">Latence Moyenne</div>
        </div>
        <div class="metric-box">
            <div class="metric-val">{total_calls}</div>
            <div class="metric-label">Appels Totaux</div>
        </div>
    </div>

    <div class="card">
        <h2>📉 Analyse de Dérive des Données (Data Drift)</h2>
        <p>Comparaison statistique (Test KS) entre Données d'Entraînement et Production.</p>
        <p><strong>Colonnes en alerte :</strong> <span class="{'alert' if alerts_drift > 0 else ''}" style="font-weight:bold; font-size:1.2em">{alerts_drift}</span> / {len(common_cols)}</p>
        
        <div style="max-height: 500px; overflow-y: auto;">
            {df_drift.to_html(index=False, classes='table').replace('🔴 OUI', '<span style="color:red; font-weight:bold">🔴 OUI</span>')}
        </div>
    </div>
</body>
</html>
"""

with open(REPORT_OUTPUT_PATH, "w", encoding="utf-8") as f:
    f.write(html_content)

print(f"\n✅ RAPPORT COMPLET GÉNÉRÉ : {os.path.abspath(REPORT_OUTPUT_PATH)}")
print(f"📊 Métriques : {error_rate}% Erreur | {avg_latency:.1f}ms Latence | {alerts_drift} Drifts")
# Out:
# 1️⃣ Chargement Référence...
# 2️⃣ Analyse des Logs Opérationnels...
# 3️⃣ Préparation Analyse Drift...
# 4️⃣ Génération du Rapport...
#
# ✅ RAPPORT COMPLET GÉNÉRÉ : /Users/chrismaker/Documents/_Formation_AI/Projet_8/pret_a_depenser/reports/monitoring_report_complete.html
# 📊 Métriques : 0.0% Erreur | 5.2ms Latence | 35 Drifts

# %%
import pandas as pd
import matplotlib
matplotlib.use("Agg")  # backend non interactif
import json
import os
import nannyml as nml

# --- Chemins ---
BASE_DIR = ".." 
REF_DATA_PATH = os.path.join(BASE_DIR, "datas/02_preprocess/datas.csv")
PROD_LOG_PATH = os.path.join(BASE_DIR, "api/production_logs/prediction_log.jsonl")
REPORT_OUTPUT_PATH = os.path.join(BASE_DIR, "reports/drift_report_nannyml.html")

os.makedirs(os.path.dirname(REPORT_OUTPUT_PATH), exist_ok=True)

# --- 1. Chargement Référence ---
print("Chargement référence...")
reference_data = pd.read_csv(REF_DATA_PATH, index_col=0) 
if 'TARGET' in reference_data.columns:
    reference_data = reference_data.drop(columns=['TARGET'])

# --- 2. Chargement Production ---
print("Chargement logs production...")
production_records = []
try:
    with open(PROD_LOG_PATH, 'r') as f:
        for line in f:
            try:
                log = json.loads(line)
                if log.get('status') == 'SUCCESS':
                    production_records.append(log['input_features'])
            except:
                continue
except FileNotFoundError:
    print("⚠️ Pas de logs.")
    
if not production_records:
    print("⚠️ Fichier vide ou introuvable. Arrêt.")
else:
    production_data = pd.DataFrame.from_records(production_records)
    # Alignement et conversion
    production_data = production_data[reference_data.columns]
    production_data = production_data.astype(reference_data.dtypes)
    print(f"✅ {len(production_data)} logs chargés.")

    # Ajout Timestamps fictifs
    reference_data['timestamp'] = pd.date_range(start='2024-01-01', periods=len(reference_data), freq='h')
    production_data['timestamp'] = pd.date_range(start='2025-01-01', periods=len(production_data), freq='h')

    # --- 3. Calcul Drift (La Correction est ICI) ---
    print("Calcul NannyML en cours...")
    
    features = [c for c in reference_data.columns if c != 'timestamp']
    
    calc = nml.UnivariateDriftCalculator(
        column_names=features,
        timestamp_column_name='timestamp',
        continuous_methods=['kolmogorov_smirnov'],
        categorical_methods=['chi2'],
        chunk_number=1  # <--- FORCE 1 SEUL BLOC (Obligatoire pour < 50 lignes)
    )
    
    calc.fit(reference_data)
    results = calc.calculate(production_data)
    
    # --- 4. Rapport ---
    figure = results.plot()
    figure.write_html(REPORT_OUTPUT_PATH)
    print(f"✅ Rapport généré : {os.path.abspath(REPORT_OUTPUT_PATH)}")
    
    # --- 5. Résultats Console ---
    drift_metrics = results.to_df()
    # On regarde les alertes sur le seul et unique chunk
    alert_count = drift_metrics.loc[:, (slice(None), 'alert')].iloc[0].sum()
    print(f"\n--- 📊 RÉSULTAT : {alert_count} alertes détectées ---")

# %%
import matplotlib
matplotlib.use("Agg")  # IMPORTANT : empêche matplotlib de bloquer

import pandas as pd
import json
import os
import nannyml as nml

BASE_DIR = ".."
REF_DATA_PATH = os.path.join(BASE_DIR, "datas/02_preprocess/datas.csv")
PROD_LOG_PATH = os.path.join(BASE_DIR, "api/production_logs/prediction_log.jsonl")
REPORT_OUTPUT_PATH = os.path.join(BASE_DIR, "reports/drift_report_nannyml.html")

os.makedirs(os.path.dirname(REPORT_OUTPUT_PATH), exist_ok=True)

print("Chargement référence...")
reference_data = pd.read_csv(REF_DATA_PATH, index_col=0)

# Optionnel : enlever la cible
if 'TARGET' in reference_data.columns:
    reference_data = reference_data.drop(columns=['TARGET'])

# ⚡ Réduction massive du dataset (obligatoire pour NannyML)
reference_data = reference_data.sample(500, random_state=42)

print("Chargement production...")
production_records = []
try:
    with open(PROD_LOG_PATH, 'r') as f:
        for line in f:
            log = json.loads(line)
            if log.get("status") == "SUCCESS":
                production_records.append(log["input_features"])
except FileNotFoundError:
    print("⚠️ Pas de logs.")

if not production_records:
    print("⚠️ Aucun log")
    exit()

production_data = pd.DataFrame.from_records(production_records)
production_data = production_data[reference_data.columns]  # mêmes colonnes

reference_data["timestamp"] = pd.date_range(start='2024-01-01', periods=len(reference_data), freq='h')
production_data["timestamp"] = pd.date_range(start='2025-01-01', periods=len(production_data), freq='h')

features = [c for c in reference_data.columns if c != "timestamp"]

print("Calcul du drift...")
calc = nml.UnivariateDriftCalculator(
    column_names=features,
    timestamp_column_name="timestamp",
    continuous_methods=["kolmogorov_smirnov"],
    categorical_methods=["chi2"],
    chunk_size=len(production_data),  # 1 chunk
)

calc.fit(reference_data)
results = calc.calculate(production_data)

print("Génération du rapport...")
fig = results.plot()
fig.write_html(REPORT_OUTPUT_PATH)

print("Fini.")
# Out:
# Chargement référence...
# Chargement production...
# Calcul du drift...
# Génération du rapport...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 62
#      59 results = calc.calculate(production_data)
#      61 print("Génération du rapport...")
# ---> 62 fig = results.plot()
#      63 fig.write_html(REPORT_OUTPUT_PATH)
#      65 print("Fini.")
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/nannyml/usage_logging.py:242, in log_usage.<locals>.logging_decorator.<locals>.logging_wrapper(*args, **kwargs)
#     240 finally:
#     241     if runtime_exception is not None:
# --> 242         raise runtime_exception
#     243     else:
#     244         return res
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/nannyml/usage_logging.py:191, in log_usage.<locals>.logging_decorator.<locals>.logging_wrapper(*args, **kwargs)
#     188 runtime_exception = None
#     189 try:
#     190     # run original function
# --> 191     res = func(*args, **kwargs)
#     192 except BaseException as exc:
#     193     runtime_exception = exc
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/nannyml/drift/univariate/result.py:237, in Result.plot(self, kind, *args, **kwargs)
#     195 """Renders plots for metrics returned by the univariate distance drift calculator.
#     196
#     197 For any feature you can render the statistic value or p-values as a step plot, or create a distribution plot.
#    (...)    234
#     235 """
#     236 if kind == 'drift':
# --> 237     return plot_metrics(
#     238         self,
#     239         title='Univariate drift metrics',
#     240         hover=Hover(
#     241             template='%{period} &nbsp; &nbsp; %{alert} <br />'
#     242             'Chunk: <b>%{chunk_key}</b> &nbsp; &nbsp; %{x_coordinate} <br />'
#     243             '%{metric_name}: <b>%{metric_value}</b><b r />',
#     244             show_extra=True,
#     245         ),
#     246         subplot_title_format='{display_names[1]} for <b>{display_names[0]}</b>',
#     247         subplot_y_axis_title_format='{display_names[1]}',
#     248         color=Colors.BLUE_SKY_CRAYOLA,
#     249         metric_name='Method',
#     250     )
#     251 elif kind == 'distribution':
#     252     return plot_distributions(
#     253         self,
#     254         reference_data=self.reference_data,
#     255         analysis_data=self.analysis_data,
#     256         chunker=self.chunker,
#     257     )
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/nannyml/plots/blueprints/metrics.py:60, in plot_metrics(result, title, x_axis_time_title, x_axis_chunk_title, y_axis_title, figure_args, subplot_title_format, subplot_y_axis_title_format, number_of_columns, hover, **kwargs)
#      57     row = (idx // number_of_columns) + 1
#      58     col = (idx % number_of_columns) + 1
# ---> 60     figure = _plot_metric(
#      61         figure=figure,
#      62         row=row,
#      63         col=col,
#      64         metric_display_name=subplot_title_format.format(display_names=key.display_names),
#      65         reference_metric=reference_result.values(key),
#      66         reference_alerts=reference_result.alerts(key),
#      67         reference_chunk_keys=reference_result.chunk_keys,
#      68         reference_chunk_periods=reference_result.chunk_periods,
#      69         reference_chunk_indices=reference_result.chunk_indices,
#      70         reference_chunk_start_dates=reference_result.chunk_start_dates,
#      71         reference_chunk_end_dates=reference_result.chunk_end_dates,
#      72         reference_upper_thresholds=reference_result.upper_thresholds(key),
#      73         reference_lower_thresholds=reference_result.lower_thresholds(key),
#      74         reference_upper_confidence_boundary=reference_result.upper_confidence_bounds(key),
#      75         reference_lower_confidence_boundary=reference_result.lower_confidence_bounds(key),
#      76         reference_sampling_error=reference_result.sampling_error(key),
#      77         analysis_metric=analysis_result.values(key),
#      78         analysis_alerts=analysis_result.alerts(key),
#      79         analysis_chunk_keys=analysis_result.chunk_keys,
#      80         analysis_chunk_periods=analysis_result.chunk_periods,
#      81         analysis_chunk_indices=analysis_result.chunk_indices,
#      82         analysis_chunk_start_dates=analysis_result.chunk_start_dates,
#      83         analysis_chunk_end_dates=analysis_result.chunk_end_dates,
#      84         analysis_upper_thresholds=analysis_result.upper_thresholds(key),
#      85         analysis_lower_thresholds=analysis_result.lower_thresholds(key),
#      86         analysis_upper_confidence_boundary=analysis_result.upper_confidence_bounds(key),
#      87         analysis_lower_confidence_boundary=analysis_result.lower_confidence_bounds(key),
#      88         analysis_sampling_error=analysis_result.sampling_error(key),
#      89         hover=hover,
#      90         subplot_y_axis_title=subplot_y_axis_title_format.format(display_names=key.display_names),
#      91         **kwargs,
#      92     )
#      94 return figure
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/nannyml/plots/blueprints/metrics.py:436, in _plot_metric(figure, metric_display_name, analysis_metric, reference_metric, reference_alerts, reference_chunk_keys, reference_chunk_periods, reference_chunk_indices, reference_chunk_start_dates, reference_chunk_end_dates, reference_upper_thresholds, reference_lower_thresholds, reference_upper_confidence_boundary, reference_lower_confidence_boundary, reference_sampling_error, analysis_alerts, analysis_chunk_keys, analysis_chunk_periods, analysis_chunk_indices, analysis_chunk_start_dates, analysis_chunk_end_dates, analysis_upper_thresholds, analysis_lower_thresholds, analysis_upper_confidence_boundary, analysis_lower_confidence_boundary, analysis_sampling_error, row, col, hover, subplot_y_axis_title, color, metric_name, **kwargs)
#     433 if has_reference_results:
#     434     is_time_based = is_time_based_x_axis(reference_chunk_start_dates, reference_chunk_end_dates)
# --> 436     figure.add_period_separator(
#     437         x=(
#     438             ensure_numpy(reference_chunk_indices)[0][-1] + 1
#     439             if not is_time_based
#     440             else ensure_numpy(analysis_chunk_start_dates)[0][0]
#     441         )
#     442     )
#     444     reference_period_text_x = (
#     445         reference_chunk_indices.mean() if not is_time_based else reference_chunk_start_dates.mean()  # type: ignore
#     446     )
#     448     figure.add_annotation(
#     449         x=reference_period_text_x,
#     450         xshift=10,
#    (...)    456         col=col,
#     457     )
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/nannyml/plots/components/figure.py:104, in Figure.add_period_separator(self, x, color, subplot_args, **kwargs)
#     101 if subplot_args is not None:
#     102     kwargs.update(dict(col=subplot_args.get('col'), row=subplot_args.get('row')))
# --> 104 self.add_vline(x=x, line=dict(color=color, width=1), layer='below', **kwargs)
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/plotly/graph_objs/_figure.py:1049, in Figure.add_vline(self, x, row, col, exclude_empty_subplots, annotation, **kwargs)
#    1001 def add_vline(
#    1002     self,
#    1003     x,
#    (...)   1008     **kwargs,
#    1009 ) -> "Figure":
#    1010     """
#    1011
#    1012     Add a vertical line to a plot or subplot that extends infinitely in the
#    (...)   1047         except for x0, x1, y0, y1 or type.
#    1048     """
# -> 1049     return super(Figure, self).add_vline(
#    1050         x, row, col, exclude_empty_subplots, annotation, **kwargs
#    1051     )
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/plotly/basedatatypes.py:4095, in BaseFigure.add_vline(self, x, row, col, exclude_empty_subplots, annotation, **kwargs)
#    4086 def add_vline(
#    4087     self,
#    4088     x,
#    (...)   4093     **kwargs,
#    4094 ):
# -> 4095     self._process_multiple_axis_spanning_shapes(
#    4096         dict(type="line", x0=x, x1=x, y0=0, y1=1),
#    4097         row,
#    4098         col,
#    4099         "vline",
#    4100         exclude_empty_subplots=exclude_empty_subplots,
#    4101         annotation=annotation,
#    4102         **kwargs,
#    4103     )
#    4104     return self
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/plotly/basedatatypes.py:4039, in BaseFigure._process_multiple_axis_spanning_shapes(self, shape_args, row, col, shape_type, exclude_empty_subplots, annotation, **kwargs)
#    4033 shape_kwargs, annotation_kwargs = shapeannotation.split_dict_by_key_prefix(
#    4034     kwargs, "annotation_"
#    4035 )
#    4036 augmented_annotation = shapeannotation.axis_spanning_shape_annotation(
#    4037     annotation, shape_type, shape_args, annotation_kwargs
#    4038 )
# -> 4039 self.add_shape(
#    4040     row=row,
#    4041     col=col,
#    4042     exclude_empty_subplots=exclude_empty_subplots,
#    4043     **_combine_dicts([shape_args, shape_kwargs]),
#    4044 )
#    4045 if augmented_annotation is not None:
#    4046     self.add_annotation(
#    4047         augmented_annotation,
#    4048         row=row,
#    (...)   4051         yref=shape_kwargs.get("yref", "y"),
#    4052     )
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/plotly/graph_objs/_figure.py:25665, in Figure.add_shape(self, arg, editable, fillcolor, fillrule, label, layer, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, line, name, opacity, path, showlegend, templateitemname, type, visible, x0, x0shift, x1, x1shift, xanchor, xref, xsizemode, y0, y0shift, y1, y1shift, yanchor, yref, ysizemode, row, col, secondary_y, exclude_empty_subplots, **kwargs)
#   25627 from plotly.graph_objs import layout as _layout
#   25629 new_obj = _layout.Shape(
#   25630     arg,
#   25631     editable=editable,
#    (...)  25663     **kwargs,
#   25664 )
# > 25665 return self._add_annotation_like(
#   25666     "shape",
#   25667     "shapes",
#   25668     new_obj,
#   25669     row=row,
#   25670     col=col,
#   25671     secondary_y=secondary_y,
#   25672     exclude_empty_subplots=exclude_empty_subplots,
#   25673 )
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/plotly/basedatatypes.py:1518, in BaseFigure._add_annotation_like(self, prop_singular, prop_plural, new_obj, row, col, secondary_y, exclude_empty_subplots)
#    1516     rows_cols = self._select_subplot_coordinates(row, col)
#    1517     for r, c in rows_cols:
# -> 1518         self._add_annotation_like(
#    1519             prop_singular,
#    1520             prop_plural,
#    1521             new_obj,
#    1522             row=r,
#    1523             col=c,
#    1524             secondary_y=secondary_y,
#    1525             exclude_empty_subplots=exclude_empty_subplots,
#    1526         )
#    1527     return self
#    1529 # Get grid_ref if specific row or column requested
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/plotly/basedatatypes.py:1588, in BaseFigure._add_annotation_like(self, prop_singular, prop_plural, new_obj, row, col, secondary_y, exclude_empty_subplots)
#    1584     xref = xaxis.replace("axis", "")
#    1585 # if exclude_empty_subplots is True, check to see if subplot is
#    1586 # empty and return if it is
#    1587 if exclude_empty_subplots and (
# -> 1588     not self._subplot_not_empty(
#    1589         xref, yref, selector=bool(exclude_empty_subplots)
#    1590     )
#    1591 ):
#    1592     return self
#    1593 # in case the user specified they wanted an axis to refer to the
#    1594 # domain of that axis and not the data, append ' domain' to the
#    1595 # computed axis accordingly
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/plotly/basedatatypes.py:4231, in BaseFigure._subplot_not_empty(self, xref, yref, selector)
#    4222         obj = None
#    4223     if obj:
#    4224         ret |= any(
#    4225             t == (xref, yref)
#    4226             for t in [
#    4227                 # if a object exists but has no xaxis or yaxis keys, then it
#    4228                 # is plotted with xaxis/xref 'x' and yaxis/yref 'y'
#    4229                 (
#    4230                     "x" if d[xaxiskw] is None else d[xaxiskw],
# -> 4231                     "y" if d[yaxiskw] is None else d[yaxiskw],
#    4232                 )
#    4233                 for d in obj
#    4234             ]
#    4235         )
#    4236 return ret
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/plotly/basedatatypes.py:4743, in BasePlotlyType.__getitem__(self, prop)
#    4741     return validator.present(self._compound_array_props[prop])
#    4742 elif self._props is not None and prop in self._props:
# -> 4743     return validator.present(self._props[prop])
#    4744 elif self._prop_defaults is not None:
#    4745     return validator.present(self._prop_defaults.get(prop, None))
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/plotly/basedatatypes.py:4437, in BasePlotlyType._props(self)
#    4434     return self._orphan_props
#    4435 else:
#    4436     # Get data from parent's dict
# -> 4437     return self.parent._get_child_props(self)
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/plotly/basedatatypes.py:4463, in BasePlotlyType._get_child_props(self, child)
#    4457 if child.plotly_name in self:
#    4458     from _plotly_utils.basevalidators import (
#    4459         CompoundValidator,
#    4460         CompoundArrayValidator,
#    4461     )
# -> 4463     validator = self._get_validator(child.plotly_name)
#    4465     if isinstance(validator, CompoundValidator):
#    4466         return self._props.get(child.plotly_name, None)
#
# File ~/Documents/_Formation_AI/Projet_8/pret_a_depenser/.venv/lib/python3.12/site-packages/plotly/basedatatypes.py:4393, in BasePlotlyType.plotly_name(self)
#    4386             raise err
#    4387     # No need to call _raise_on_invalid_property_error here,
#    4388     # because we have it set up so that the singular case of calling
#    4389     # __setitem__ will raise this. If _check_path_in_prop_tree
#    4390     # raised that in its travels, it will already be in the error
#    4391     # message.
# -> 4393 @property
#    4394 def plotly_name(self):
#    4395     """
#    4396     The plotly name of the object
#    4397
#    (...)   4400     str
#    4401     """
#    4402     return self._plotly_name
#
# KeyboardInterrupt:

# %%
print(len(reference_data))
# Out:
# 307507
